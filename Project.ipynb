# %%
import numpy as np
import pandas as pd
import json
import csv
import random

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

import pprint
import tensorflow.compat.v1 as tf
from tensorflow.python.framework import ops
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
tf.disable_eager_execution()

# Reading the data
data = pd.read_csv("news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# encoding the labels
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = []
text = []
labels = []
for x in range(training_size):
	title.append(data['title'][x])
	text.append(data['text'][x])
	labels.append(data['label'][x])

# %%
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(
	sequences1, padding=padding_type, truncating=trunc_type)
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
embeddings_index = {}
with open('glove.6B.50d.txt',encoding='utf-8' ) as f:
	for line in f:
		values = line.split()
		word = values[0]
		coefs = np.asarray(values[1:], dtype='float32')
		embeddings_index[word] = coefs

# Generating embeddings
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim))
for word, i in word_index1.items():
	embedding_vector = embeddings_index.get(word)
	if embedding_vector is not None:
		embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
	tf.keras.layers.Embedding(vocab_size1+1, embedding_dim,
							input_length=max_length, weights=[
								embeddings_matrix],
							trainable=False),
	tf.keras.layers.Dropout(0.2),
	tf.keras.layers.Conv1D(64, 5, activation='relu'),
	tf.keras.layers.MaxPooling1D(pool_size=4),
	tf.keras.layers.LSTM(64),
	tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
			optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 54, 50)            377600
#
#  dropout (Dropout)           (None, 54, 50)            0
#
#  conv1d (Conv1D)             (None, 50, 64)            16064
#
#  max_pooling1d (MaxPooling1D  (None, 12, 64)           0
#  )
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 426,753
# Trainable params: 49,153
# Non-trainable params: 377,600
# _________________________________________________________________

# %%
num_epochs = 50

training_padded = np.array(training_sequences1)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences1)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels,
					epochs=num_epochs,
					validation_data=(testing_padded,
									testing_labels),
					verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# C:\Users\DELL\anaconda3\lib\site-packages\keras\engine\training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2700/2700 - 4s - loss: 0.6596 - accuracy: 0.5941 - val_loss: 0.5789 - val_accuracy: 0.6933 - 4s/epoch - 2ms/sample
# Epoch 2/50
# 2700/2700 - 2s - loss: 0.5871 - accuracy: 0.6922 - val_loss: 0.5314 - val_accuracy: 0.7167 - 2s/epoch - 875us/sample
# Epoch 3/50
# 2700/2700 - 2s - loss: 0.5395 - accuracy: 0.7270 - val_loss: 0.5157 - val_accuracy: 0.7067 - 2s/epoch - 858us/sample
# Epoch 4/50
# 2700/2700 - 3s - loss: 0.4923 - accuracy: 0.7593 - val_loss: 0.4951 - val_accuracy: 0.7733 - 3s/epoch - 927us/sample
# Epoch 5/50
# 2700/2700 - 3s - loss: 0.4560 - accuracy: 0.7848 - val_loss: 0.4968 - val_accuracy: 0.7400 - 3s/epoch - 945us/sample
# Epoch 6/50
# 2700/2700 - 2s - loss: 0.4198 - accuracy: 0.8096 - val_loss: 0.4690 - val_accuracy: 0.7667 - 2s/epoch - 905us/sample
# Epoch 7/50
# 2700/2700 - 2s - loss: 0.3478 - accuracy: 0.8522 - val_loss: 0.4878 - val_accuracy: 0.7600 - 2s/epoch - 850us/sample
# Epoch 8/50
# 2700/2700 - 3s - loss: 0.3311 - accuracy: 0.8600 - val_loss: 0.5540 - val_accuracy: 0.7400 - 3s/epoch - 933us/sample
# Epoch 9/50
# 2700/2700 - 3s - loss: 0.3032 - accuracy: 0.8652 - val_loss: 0.5253 - val_accuracy: 0.7733 - 3s/epoch - 1ms/sample
# Epoch 10/50
# 2700/2700 - 3s - loss: 0.2808 - accuracy: 0.8870 - val_loss: 0.6599 - val_accuracy: 0.7433 - 3s/epoch - 1ms/sample
# Epoch 11/50
# 2700/2700 - 2s - loss: 0.2434 - accuracy: 0.9063 - val_loss: 0.5800 - val_accuracy: 0.7500 - 2s/epoch - 827us/sample
# Epoch 12/50
# 2700/2700 - 2s - loss: 0.2192 - accuracy: 0.9141 - val_loss: 0.5738 - val_accuracy: 0.7833 - 2s/epoch - 848us/sample
# Epoch 13/50
# 2700/2700 - 2s - loss: 0.2206 - accuracy: 0.9170 - val_loss: 0.5766 - val_accuracy: 0.7533 - 2s/epoch - 844us/sample
# Epoch 14/50
# 2700/2700 - 2s - loss: 0.1894 - accuracy: 0.9241 - val_loss: 0.6472 - val_accuracy: 0.7733 - 2s/epoch - 850us/sample
# Epoch 15/50
# 2700/2700 - 2s - loss: 0.1725 - accuracy: 0.9322 - val_loss: 0.5842 - val_accuracy: 0.7800 - 2s/epoch - 847us/sample
# Epoch 16/50
# 2700/2700 - 2s - loss: 0.1754 - accuracy: 0.9278 - val_loss: 0.7082 - val_accuracy: 0.7533 - 2s/epoch - 747us/sample
# Epoch 17/50
# 2700/2700 - 2s - loss: 0.1549 - accuracy: 0.9378 - val_loss: 0.6746 - val_accuracy: 0.7700 - 2s/epoch - 758us/sample
# Epoch 18/50
# 2700/2700 - 2s - loss: 0.1691 - accuracy: 0.9296 - val_loss: 0.6742 - val_accuracy: 0.7600 - 2s/epoch - 804us/sample
# Epoch 19/50
# 2700/2700 - 2s - loss: 0.1212 - accuracy: 0.9589 - val_loss: 0.8492 - val_accuracy: 0.7567 - 2s/epoch - 857us/sample
# Epoch 20/50
# 2700/2700 - 3s - loss: 0.1389 - accuracy: 0.9470 - val_loss: 0.7450 - val_accuracy: 0.7400 - 3s/epoch - 929us/sample
# Epoch 21/50
# 2700/2700 - 3s - loss: 0.1311 - accuracy: 0.9507 - val_loss: 0.7670 - val_accuracy: 0.7433 - 3s/epoch - 958us/sample
# Epoch 22/50
# 2700/2700 - 2s - loss: 0.1231 - accuracy: 0.9604 - val_loss: 0.7392 - val_accuracy: 0.7533 - 2s/epoch - 745us/sample
# Epoch 23/50
# 2700/2700 - 2s - loss: 0.1089 - accuracy: 0.9567 - val_loss: 0.7825 - val_accuracy: 0.7600 - 2s/epoch - 856us/sample
# Epoch 24/50
# 2700/2700 - 2s - loss: 0.1164 - accuracy: 0.9578 - val_loss: 0.7749 - val_accuracy: 0.7600 - 2s/epoch - 854us/sample
# Epoch 25/50
# 2700/2700 - 2s - loss: 0.0996 - accuracy: 0.9667 - val_loss: 0.8805 - val_accuracy: 0.7300 - 2s/epoch - 917us/sample
# Epoch 26/50
# 2700/2700 - 2s - loss: 0.1400 - accuracy: 0.9463 - val_loss: 0.7045 - val_accuracy: 0.7633 - 2s/epoch - 895us/sample
# Epoch 27/50
# 2700/2700 - 2s - loss: 0.0910 - accuracy: 0.9693 - val_loss: 0.8146 - val_accuracy: 0.7433 - 2s/epoch - 887us/sample
# Epoch 28/50
# 2700/2700 - 2s - loss: 0.0914 - accuracy: 0.9678 - val_loss: 0.7915 - val_accuracy: 0.7567 - 2s/epoch - 837us/sample
# Epoch 29/50
# 2700/2700 - 2s - loss: 0.0958 - accuracy: 0.9663 - val_loss: 1.0135 - val_accuracy: 0.7133 - 2s/epoch - 890us/sample
# Epoch 30/50
# 2700/2700 - 2s - loss: 0.1061 - accuracy: 0.9641 - val_loss: 0.8182 - val_accuracy: 0.7533 - 2s/epoch - 924us/sample
# Epoch 31/50
# 2700/2700 - 2s - loss: 0.0967 - accuracy: 0.9644 - val_loss: 0.8693 - val_accuracy: 0.7467 - 2s/epoch - 832us/sample
# Epoch 32/50
# 2700/2700 - 2s - loss: 0.0878 - accuracy: 0.9659 - val_loss: 0.8995 - val_accuracy: 0.7367 - 2s/epoch - 877us/sample
# Epoch 33/50
# 2700/2700 - 2s - loss: 0.0780 - accuracy: 0.9693 - val_loss: 0.8257 - val_accuracy: 0.7567 - 2s/epoch - 888us/sample
# Epoch 34/50
# 2700/2700 - 2s - loss: 0.0724 - accuracy: 0.9733 - val_loss: 0.8861 - val_accuracy: 0.7500 - 2s/epoch - 858us/sample
# Epoch 35/50
# 2700/2700 - 2s - loss: 0.1009 - accuracy: 0.9570 - val_loss: 0.8442 - val_accuracy: 0.7267 - 2s/epoch - 884us/sample
# Epoch 36/50
# 2700/2700 - 2s - loss: 0.0679 - accuracy: 0.9726 - val_loss: 0.8950 - val_accuracy: 0.7433 - 2s/epoch - 849us/sample
# Epoch 37/50
# 2700/2700 - 2s - loss: 0.0753 - accuracy: 0.9733 - val_loss: 0.9477 - val_accuracy: 0.7400 - 2s/epoch - 856us/sample
# Epoch 38/50
# 2700/2700 - 2s - loss: 0.0592 - accuracy: 0.9819 - val_loss: 0.9593 - val_accuracy: 0.7433 - 2s/epoch - 893us/sample
# Epoch 39/50
# 2700/2700 - 2s - loss: 0.0785 - accuracy: 0.9726 - val_loss: 0.8907 - val_accuracy: 0.7300 - 2s/epoch - 867us/sample
# Epoch 40/50
# 2700/2700 - 2s - loss: 0.0657 - accuracy: 0.9781 - val_loss: 1.0117 - val_accuracy: 0.7367 - 2s/epoch - 853us/sample
# Epoch 41/50
# 2700/2700 - 2s - loss: 0.0616 - accuracy: 0.9759 - val_loss: 0.9498 - val_accuracy: 0.7467 - 2s/epoch - 875us/sample
# Epoch 42/50
# 2700/2700 - 2s - loss: 0.0583 - accuracy: 0.9774 - val_loss: 0.8915 - val_accuracy: 0.7500 - 2s/epoch - 860us/sample
# Epoch 43/50
# 2700/2700 - 2s - loss: 0.0700 - accuracy: 0.9756 - val_loss: 0.8968 - val_accuracy: 0.7500 - 2s/epoch - 849us/sample
# Epoch 44/50
# 2700/2700 - 2s - loss: 0.0535 - accuracy: 0.9804 - val_loss: 1.1733 - val_accuracy: 0.7467 - 2s/epoch - 876us/sample
# Epoch 45/50
# 2700/2700 - 2s - loss: 0.0748 - accuracy: 0.9733 - val_loss: 0.9497 - val_accuracy: 0.7367 - 2s/epoch - 853us/sample
# Epoch 46/50
# 2700/2700 - 2s - loss: 0.0737 - accuracy: 0.9733 - val_loss: 1.0063 - val_accuracy: 0.7267 - 2s/epoch - 863us/sample
# Epoch 47/50
# 2700/2700 - 2s - loss: 0.0672 - accuracy: 0.9759 - val_loss: 0.9330 - val_accuracy: 0.7533 - 2s/epoch - 880us/sample
# Epoch 48/50
# 2700/2700 - 2s - loss: 0.0824 - accuracy: 0.9711 - val_loss: 0.9195 - val_accuracy: 0.7500 - 2s/epoch - 840us/sample
# Epoch 49/50
# 2700/2700 - 2s - loss: 0.0739 - accuracy: 0.9733 - val_loss: 0.9281 - val_accuracy: 0.7433 - 2s/epoch - 872us/sample
# Epoch 50/50
# 2700/2700 - 2s - loss: 0.0559 - accuracy: 0.9796 - val_loss: 1.0280 - val_accuracy: 0.7433 - 2s/epoch - 884us/sample

# %%
# sample text to check if fake or not
X = "Karry to go to France in gesture of sympathy"

# detection
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\keras\engine\training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# This news is false
